# %%
import pandas as pd

# %%
import csv

# Open and read the CSV file using the csv module
csv_file_path = "/kaggle/input/nasdaq/Nasdaq_stocks.csv"
rows = []

with open(csv_file_path, 'r', encoding='utf-8', errors='ignore') as csvfile:
    csvreader = csv.reader(csvfile)
    for row in csvreader:
        rows.append(row)

# Create a DataFrame from the list of rows
nasdaq_stocks = pd.DataFrame(rows[1:], columns=rows[0])

nasdaq_stocks.shape
# Out:
# (51024, 13)

# %%
import csv

# Open and read the CSV file using the csv module
csv_file_path = "/kaggle/input/nasdaq/Nasdaq_stocks.csv"
rows = []

with open(csv_file_path, 'r', encoding='utf-8', errors='ignore') as csvfile:
    csvreader = csv.reader(csvfile)
    for row in csvreader:
        rows.append(row)

# Create a DataFrame from the list of rows
external_news = pd.DataFrame(rows[1:], columns=rows[0])

external_news.shape
# Out:
# (51024, 13)

# %%
stocks = pd.concat([nasdaq_stocks, external_news], axis=0)

# %%
stocks_data = stocks[['Date','Article_title','Stock_symbol']]
# Convert 'date' column to datetime type
stocks_data.loc[:, 'Date'] = pd.to_datetime(stocks_data['Date'], utc=True)

# Filter data for the years 2015 to 2023
start_date = pd.Timestamp('2015-01-01',tz="UTC")
end_date = pd.Timestamp('2023-12-31',tz="UTC")

stocks_data = stocks_data[(stocks_data['Date'] >= start_date) & (stocks_data['Date'] <= end_date)]
stocks_data.loc[:, 'Date'] = stocks_data['Date'].astype('str')
# Extract date component as string 'YYYY-MM-DD' using string manipulation
stocks_data.loc[:, 'Date'] = stocks_data['Date'].str.split().str[0]
stocks_data.head(30)
# Out:
#           Date                                      Article_title Stock_symbol
# 0   2023-12-16  My 6 Largest Portfolio Holdings Heading Into 2...         AAPL
# 1   2023-12-16  Brokers Suggest Investing in Apple (AAPL): Rea...         AAPL
# 2   2023-12-16                      Company News for Dec 19, 2023         AAPL
# 3   2023-12-16  NVIDIA (NVDA) Up 243% YTD: Will It Carry Momen...         AAPL
# 4   2023-12-16  Pre-Market Most Active for Dec 19, 2023 : BMY,...         AAPL
# 5   2023-12-16  3 Artificial Intelligence (AI) Stocks for 2024...         AAPL
# 6   2023-12-16                   AAPL Quantitative Stock Analysis         AAPL
# 7   2023-12-16  Should Vanguard S&P 500 ETF (VOO) Be on Your I...         AAPL
# 8   2023-12-16  Is FlexShares Quality Dividend ETF (QDF) a Str...         AAPL
# 9   2023-12-16  Is FlexShares STOXX US ESG Select Index Fund (...         AAPL
# 10  2023-12-16  Wall St futures inch up as investors pin hopes...         AAPL
# 11  2023-12-16  49.1% of Warren Buffett's $373 Billion Portfol...         AAPL
# 12  2023-12-16       2 Top Warren Buffett Stocks to Buy Right Now         AAPL
# 13  2023-12-16  TSMC to promote from within after chairman ret...         AAPL
# 14  2023-12-16  US STOCKS-Wall Street ends higher, extending r...         AAPL
# 15  2023-12-16  After Hours Most Active for Dec 18, 2023 : PAC...         AAPL
# 16  2023-12-16  Technology Sector Update for 12/18/2023: PCT, ...         AAPL
# 17  2023-12-16  Wall Street ends higher, extending rate-cut rally         AAPL
# 51002  2018-10-26  Your Dogs Of The Dow October Update By Dividen...
# 51003  2018-10-26  Stock Market Stabs Lower, Dashing Hopes For Ne...
# 51004  2018-10-26  Correction Deepens As Stocks Crumble On Amazon...
# 51005  2018-10-26  Intel (INTC) Beats on Q3 Earnings & Revenues, ...
# 51006  2018-10-26                       AMD: Why I Loved Q3 Earnings
# 51007  2018-10-26  Chipmakers' Earnings Disappoint: More Trouble ...
# 51008  2018-10-26  Stock Futures Follow Alphabet, Amazon Lower; O...
# 51009  2018-10-26  Dow 30 Stock Roundup: Boeing, Caterpillar, Int...
# 51010  2018-10-26  Wild Ride Ahead Of GDP Data (Wall Street Break...
# 51011  2018-10-26  Wall Street Breakfast: Wild Ride Ahead Of GDP ...
# 51012  2018-10-25  Intel (INTC) Q3 2018 Results - Earnings Call T...
# 51013  2018-10-25  Intel Corporation 2018 Q3 - Results - Earnings...
# 51014  2018-10-25  Dow Jones Futures Fall On Earnings: Here Are 5...
# 51015  2018-10-25  New Batch of Q3 Earnings: AMZN, GOOGL, INTC & ...
# 51016  2018-10-25  Intel +3.6% on beats, Data Center recovery, an...
# 51017  2018-10-25             Intel beats by $0.25, beats on revenue
# 51018  2018-10-25  Dow Soars 470 Points As Apple, Microsoft Lead ...
# 51019  2018-10-25                            Intel Q3: What to watch
# 51020  2018-10-25   Why October Spells Doom for Semis: ETFs in Focus
# 51021  2018-10-25              The Signal Event - Will The Dam Hold?
# 51022  2018-10-25  Analysts adjust AMD targets, comment on that r...
# 51023  2018-10-25                                 AMD Tanks (A Lot!)
#
#       Stock_symbol
# 50974         INTC
# 50975         INTC
# 50976         INTC
# 50977         INTC
# 50978         INTC
# 50979         INTC
# 50980         INTC
# 50981         INTC
# 50982         INTC
# 50983         INTC
# 50984         INTC
# 50985         INTC
# 50986         INTC
# 50987         INTC
# 50988         INTC
# 50989         INTC
# 50990         INTC
# 50991         INTC
# 50992         INTC
# 50993         INTC
# 50994         INTC
# 50995         INTC
# 50996         INTC
# 50997         INTC
# 50998         INTC
# 50999         INTC
# 51000         INTC
# 51001         INTC
# 51002         INTC
# 51003         INTC
# 51004         INTC
# 51005         INTC
# 51006         INTC
# 51007         INTC
# 51008         INTC
# 51009         INTC
# 51010         INTC
# 51011         INTC
# 51012         INTC
# 51013         INTC
# 51014         INTC
# 51015         INTC
# 51016         INTC
# 51017         INTC
# 51018         INTC
# 51019         INTC
# 51020         INTC
# 51021         INTC
# 51022         INTC
# 51023         INTC

# %%
# Extract oldest and latest dates from the sorted DataFrame
oldest_date = stocks_data.sort_values(by='Date').min()
latest_date = stocks_data.sort_values(by='Date').max()

print("\nOldest Date:", oldest_date)
print("Latest Date:", latest_date)
# Out:
# Oldest Date: Date                                                    2015-01-05
# Article_title    "9 Foolish Truths That I Hold to Be Self-Evident"
# Stock_symbol                                                  AAPL
# dtype: object
# Latest Date: Date                                                    2023-12-16
# Article_title    📈 Two Charts Show That Biotech Is in for a Sto...
# Stock_symbol                                                  NVDA
# dtype: object
